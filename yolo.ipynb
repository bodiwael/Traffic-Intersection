# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.5 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="oQ692CLu27UxO6QRtTQf")
project = rf.workspace("aivision-embeq").project("traffic-vrwv4")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-2 in yolov8:: 100%|██████████| 904/904 [00:00<00:00, 5732.39it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Traffic-2/data.yaml epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.250 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files

# Compress the folder before downloading
# !zip -r /content/runs_detect_train.zip /content/runs/detect/train2

# Download the compressed file
files.download('/content/runs_detect_train.zip')
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/BoxF1_curve.png (deflated 16%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 48%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 36%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/BoxP_curve.png (deflated 19%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train2/args.yaml (deflated 53%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 4%)
#   adding: content/runs/detect/train2/train_batch1040.jpg (deflated 12%)
#   adding: content/runs/detect/train2/results.png (deflated 9%)
#   adding: content/runs/detect/train2/results.csv (deflated 64%)
# ...
